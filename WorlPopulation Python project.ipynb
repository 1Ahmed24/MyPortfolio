# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ahmed\jupyter,python\pandas\world_population.csv")

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df[df['Rank']<= 10]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# ...

# %%
two_countries = ['Indonesia','Russia']
df[df['Country'].isin(two_countries)]
# Out:
#      Rank CCA3    Country  Capital Continent  2022 Population  \
# 93      4  IDN  Indonesia  Jakarta      Asia      275501339.0
# 171     9  RUS     Russia   Moscow    Europe      144713314.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 93       271857970.0      259091970.0      244016173.0      214072421.0
# 171      145617329.0      144668389.0      143242599.0      146844839.0
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 93       182159874.0      148177096.0      115228394.0   1904569.0
# 171      148005704.0      138257420.0      130093010.0  17098242.0
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 93            144.6529       1.0064                         3.45
# 171             8.4636       0.9973                         1.81

# %%
df[df['Country'].str.contains('Kingdom')]
# Out:
#      Rank CCA3         Country Capital Continent  2022 Population  \
# 220    21  GBR  United Kingdom  London    Europe       67508936.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 220       67059474.0       65224364.0       62760039.0       58850043.0
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 220       57210442.0       56326328.0       55650166.0    242900.0
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 220           277.9289       1.0034                         0.85

# %%
df[df['Country'].str.contains('E')]
# Out:
#      Rank CCA3               Country       Capital      Continent  \
# 56     67  ECU               Ecuador         Quito  South America
# 57     14  EGY                 Egypt         Cairo         Africa
# 58    112  SLV           El Salvador  San Salvador  North America
# 59    152  GNQ     Equatorial Guinea        Malabo         Africa
# 60    132  ERI               Eritrea        Asmara         Africa
# 61    156  EST               Estonia       Tallinn         Europe
# 62    159  SWZ              Eswatini       Mbabane         Africa
# 63     12  ETH              Ethiopia   Addis Ababa         Africa
# 219    97  ARE  United Arab Emirates     Abu Dhabi           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 56        18001000.0       17588595.0       16195902.0       14989585.0
# 57       110990103.0      107465134.0       97723799.0       87252413.0
# 58         6336392.0        6292731.0        6231066.0        6114034.0
# ...

# %%
df[df['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
df1 = df.set_index('Country')

# %%
df1.filter(items=['Continent','Rank'])
# Out:
#                   Continent  Rank
# Country
# Afghanistan            Asia    36
# Albania              Europe   138
# Algeria              Africa    34
# American Samoa      Oceania   213
# Andorra              Europe   203
# ...                     ...   ...
# Wallis and Futuna   Oceania   226
# Western Sahara       Africa   172
# Yemen                  Asia    46
# Zambia               Africa    63
# Zimbabwe             Africa    74
#
# [234 rows x 2 columns]

# %%
df1.filter(items=['Continent','Rank'],axis = 0)
# Out:
# Empty DataFrame
# Columns: [Rank, CCA3, Capital, Continent, 2022 Population, 2020 Population, 2015 Population, 2010 Population, 2000 Population, 1990 Population, 1980 Population, 1970 Population, Area (km²), Density (per km²), Growth Rate, World Population Percentage]
# Index: []

# %%
df1.filter(items=['Qatar'],axis = 0)
# Out:
#        Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Qatar   143  QAT    Doha      Asia        2695122.0        2760385.0
#
#        2015 Population  2010 Population  2000 Population  1990 Population  \
# Qatar        2414573.0        1713504.0         645937.0         441675.0
#
#        1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Qatar         277450.0         118007.0     11586.0           232.6189
#
#        Growth Rate  World Population Percentage
# Qatar       1.0026                         0.03

# %%
df1.filter(like='Qatar',axis = 0)
# Out:
#          Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Country
# Qatar     143  QAT    Doha      Asia        2695122.0        2760385.0
#
#          2015 Population  2010 Population  2000 Population  1990 Population  \
# Country
# Qatar          2414573.0        1713504.0         645937.0         441675.0
#
#          1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Country
# Qatar           277450.0         118007.0     11586.0           232.6189
#
#          Growth Rate  World Population Percentage
# Country
# Qatar         1.0026                         0.03

# %%
df1.loc['Qatar'] #str
# Out:
# Rank                                 143
# CCA3                                 QAT
# Capital                             Doha
# Continent                           Asia
# 2022 Population                2695122.0
# 2020 Population                2760385.0
# 2015 Population                2414573.0
# 2010 Population                1713504.0
# 2000 Population                 645937.0
# 1990 Population                 441675.0
# 1980 Population                 277450.0
# 1970 Population                 118007.0
# Area (km²)                       11586.0
# Density (per km²)               232.6189
# Growth Rate                       1.0026
# World Population Percentage         0.03
# Name: Qatar, dtype: object

# %%
df1.iloc[56] #int
# Out:
# Rank                                      67
# CCA3                                     ECU
# Capital                                Quito
# Continent                      South America
# 2022 Population                   18001000.0
# 2020 Population                   17588595.0
# 2015 Population                   16195902.0
# 2010 Population                   14989585.0
# 2000 Population                   12626507.0
# 1990 Population                   10449837.0
# 1980 Population                    8135845.0
# 1970 Population                    6172215.0
# Area (km²)                          276841.0
# Density (per km²)                    65.0229
# Growth Rate                           1.0114
# World Population Percentage             0.23
# Name: Ecuador, dtype: object

# %%
df[df['Rank']<15]. sort_values(by='2022 Population',ascending=False)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
# 102    11  JPN          Japan             Tokyo           Asia
# 63     12  ETH       Ethiopia       Addis Ababa         Africa
# 163    13  PHL    Philippines            Manila           Asia
# 57     14  EGY          Egypt             Cairo         Africa
#
# ...

# %%
df[df['Rank']<15]. sort_values(by='2022 Population',ascending=True)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 57     14  EGY          Egypt             Cairo         Africa
# 163    13  PHL    Philippines            Manila           Asia
# 63     12  ETH       Ethiopia       Addis Ababa         Africa
# 102    11  JPN          Japan             Tokyo           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 92      2  IND          India         New Delhi           Asia
# 41      1  CHN          China           Beijing           Asia
#
# ...

# %%
df[df['Rank']<15]. sort_values(by=['Rank','2022 Population'],ascending=True)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
# 102    11  JPN          Japan             Tokyo           Asia
# 63     12  ETH       Ethiopia       Addis Ababa         Africa
# 163    13  PHL    Philippines            Manila           Asia
# 57     14  EGY          Egypt             Cairo         Africa
#
# ...

# %%
df[df['Rank']<15]. sort_values(by=['Country','Rank'],ascending=True)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 57     14  EGY          Egypt             Cairo         Africa
# 63     12  ETH       Ethiopia       Addis Ababa         Africa
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 102    11  JPN          Japan             Tokyo           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 163    13  PHL    Philippines            Manila           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
# ...

# %%
df[df['Rank']<15]. sort_values(by=['Continent','Country'],ascending=[False,True])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 27      7  BRA         Brazil          Brasilia  South America
# 131    10  MEX         Mexico       Mexico City  North America
# 221     3  USA  United States  Washington, D.C.  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 102    11  JPN          Japan             Tokyo           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 163    13  PHL    Philippines            Manila           Asia
# 57     14  EGY          Egypt             Cairo         Africa
# 63     12  ETH       Ethiopia       Addis Ababa         Africa
# 149     6  NGA        Nigeria             Abuja         Africa
#
# ...
